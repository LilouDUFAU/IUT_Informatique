# %% [markdown]
# # R4.04 - Méthode d'optimisation

# %% [markdown]
# ## Fiche 3

# %% [markdown]
# #### Import des bibliothèques

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# ### Étape 1 : Chargement et filtrage des données

# %%
# Définition des chemins vers les fichiers de données
fichier_ancien = "online_retail_2009-2010.csv"  
fichier_recent = "online_retail_2010_2011.csv"

# Importation des données
ancien_dataset = pd.read_csv(fichier_ancien, sep=";", encoding="latin1")
recent_dataset = pd.read_csv(fichier_recent, sep=";", encoding="latin1")

# Fusion des données
ensemble_donnees = pd.concat([ancien_dataset, recent_dataset])

# Filtrage des données pour ne conserver que les transactions en France
donnees_france = ensemble_donnees[ensemble_donnees['Country'] == "France"]

# %% [markdown]
# ### Étape 2 : Préparation des données pour l'algorithme Apriori

# %% [markdown]
# Génère une matrice où chaque ligne est une facture, chaque colonne est un produit, et les valeurs sont les quantités achetées.

# %%
pivot_table = pd.crosstab(donnees_france['Invoice'], donnees_france['Description'])
pivot_table
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# Invoice
# 489439                                    0                   0
# 489557                                    0                   0
# 489883                                    0                   0
# 490139                                    0                   0
# 490152                                    0                   0
# ...                                     ...                 ...
# C579532                                   0                   0
# C579562                                   0                   0
# C580161                                   0                   0
# C580263                                   0                   0
# C581316                                   0                   0
#
# Description   FLAMINGO LIGHTS   I LOVE LONDON MINI BACKPACK  \
# Invoice
# 489439                      0                             0
# 489557                      0                             0
# 489883                      0                             0
# 490139                      0                             0
# 490152                      0                             0
# ...                       ...                           ...
# C579532                     0                             0
# C579562                     0                             0
# C580161                     0                             0
# C580263                     0                             0
# C581316                     0                             0
#
# Description   LARGE SKULL WINDMILL   NINE DRAWER OFFICE TIDY  \
# Invoice
# 489439                           0                         0
# 489557                           0                         0
# 489883                           0                         0
# 490139                           0                         0
# 490152                           0                         0
# ...                            ...                       ...
# C579532                          0                         0
# C579562                          0                         0
# C580161                          0                         0
# C580263                          0                         0
# C581316                          0                         0
#
# Description   RED/WHITE DOT MINI CASES   SET 2 TEA TOWELS I LOVE LONDON   \
# Invoice
# 489439                               0                                 0
# 489557                               0                                 0
# 489883                               1                                 0
# 490139                               0                                 0
# 490152                               1                                 0
# ...                                ...                               ...
# C579532                              0                                 0
# C579562                              0                                 0
# C580161                              0                                 0
# C580263                              0                                 0
# C581316                              0                                 0
#
# Description   SPACEBOY BABY GIFT SET   TRELLIS COAT RACK  ...  \
# Invoice                                                   ...
# 489439                             0                   0  ...
# 489557                             0                   0  ...
# 489883                             0                   0  ...
# 490139                             0                   0  ...
# 490152                             0                   0  ...
# ...                              ...                 ...  ...
# C579532                            0                   0  ...
# C579562                            0                   0  ...
# C580161                            0                   0  ...
# C580263                            0                   0  ...
# C581316                            0                   0  ...
#
# Description  YELLOW RED FLOWER PIGGY BANK  YELLOW SHARK HELICOPTER  \
# Invoice
# 489439                                  0                        0
# 489557                                  0                        0
# 489883                                  0                        0
# 490139                                  0                        0
# 490152                                  0                        0
# ...                                   ...                      ...
# C579532                                 0                        0
# C579562                                 0                        0
# C580161                                 0                        0
# C580263                                 0                        0
# C581316                                 0                        0
#
# Description  YOU'RE CONFUSING ME METAL SIGN   ZINC  STAR T-LIGHT HOLDER   \
# Invoice
# 489439                                     0                           0
# 489557                                     0                           0
# 489883                                     0                           0
# 490139                                     0                           0
# 490152                                     0                           0
# ...                                      ...                         ...
# C579532                                    0                           0
# C579562                                    0                           0
# C580161                                    0                           0
# C580263                                    0                           0
# C581316                                    0                           0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# Invoice
# 489439                               0                           0
# 489557                               0                           0
# 489883                               0                           0
# 490139                               0                           0
# 490152                               0                           0
# ...                                ...                         ...
# C579532                              0                           0
# C579562                              0                           0
# C580161                              0                           0
# C580263                              0                           0
# C581316                              0                           0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# Invoice
# 489439                                 0                               0
# 489557                                 0                               0
# 489883                                 0                               0
# 490139                                 0                               0
# 490152                                 0                               0
# ...                                  ...                             ...
# C579532                                0                               0
# C579562                                0                               0
# C580161                                0                               0
# C580263                                0                               0
# C581316                                0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL  ZINC WILLIE WINKIE  CANDLE STICK
# Invoice
# 489439                                     0                                 0
# 489557                                     0                                 0
# 489883                                     0                                 0
# 490139                                     0                                 0
# 490152                                     0                                 0
# ...                                      ...                               ...
# C579532                                    0                                 0
# C579562                                    0                                 0
# C580161                                    0                                 0
# C580263                                    0                                 0
# C581316                                    0                                 0
#
# [746 rows x 2218 columns]

# %% [markdown]
# Convertit cette matrice en booléens (`True` si un produit figure dans la facture).

# %%
binaire_table = pivot_table > 0

# %% [markdown]
# ### Étape 3 : Application de l'algorithme Apriori

# %% [markdown]
#  Trouve les ensembles d'articles fréquents (itemsets) avec un support minimum de 5%.

# %%
itemsets_frequents = apriori(binaire_table, min_support=0.05, use_colnames=True)

# %% [markdown]
# Produit des règles d'association en analysant la relation entre items avec une confiance d'au moins 80%.

# %%
regles_assoc = association_rules(itemsets_frequents, metric="confidence", min_threshold=0.8)

# %% [markdown]
# ### Étape 4 : Affichage des résultats

# %%
print("Ensembles d'articles fréquents :")
print(itemsets_frequents)

print("\nRègles d'association :")
print(regles_assoc)
len(regles_assoc)
regles_assoc
# Out:
# Ensembles d'articles fréquents :
#       support                                           itemsets
# 0    0.053619                      (4 TRADITIONAL SPINNING TOPS)
# 1    0.057641                       (ALARM CLOCK BAKELIKE GREEN)
# 2    0.060322                        (ALARM CLOCK BAKELIKE PINK)
# 3    0.056300                        (ALARM CLOCK BAKELIKE RED )
# 4    0.069705                       (ASSORTED COLOUR MINI CASES)
# ..        ...                                                ...
# 97   0.072386  (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE, PL...
# 98   0.064343  (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE, PL...
# 99   0.058981  (ROUND SNACK BOXES SET OF4 WOODLAND , POSTAGE,...
# 100  0.081769  (POSTAGE, SET/6 RED SPOTTY PAPER PLATES, SET/6...
# 101  0.058981  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
#
# [102 rows x 2 columns]
#
# Règles d'association :
#                                           antecedents  \
# 0                         (ALARM CLOCK BAKELIKE PINK)
# 1                         (ALARM CLOCK BAKELIKE RED )
# 2                        (ASSORTED COLOUR MINI CASES)
# 3                          (CIRCUS PARADE LUNCH BOX )
# 4                          (COFFEE MUG APPLES DESIGN)
# 5                           (JUMBO BAG RED RETROSPOT)
# 6                        (JUMBO BAG WOODLAND ANIMALS)
# 7                            (LUNCH BAG APPLE DESIGN)
# 8                                (LUNCH BAG WOODLAND)
# 9                           (LUNCH BOX I LOVE LONDON)
# 10                (LUNCH BOX WITH CUTLERY RETROSPOT )
# 11                  (PACK OF 72 RETROSPOT CAKE CASES)
# 12                   (PLASTERS IN TIN CIRCUS PARADE )
# 13                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 14                               (RABBIT NIGHT LIGHT)
# 15                      (RED RETROSPOT CHARLOTTE BAG)
# 16                         (RED RETROSPOT MINI CASES)
# 17                    (RED TOADSTOOL LED NIGHT LIGHT)
# 18               (ROUND SNACK BOXES SET OF 4 FRUITS )
# 19              (ROUND SNACK BOXES SET OF4 WOODLAND )
# 20              (SET/20 RED RETROSPOT PAPER NAPKINS )
# 21                      (SET/6 RED SPOTTY PAPER CUPS)
# 22                    (SET/6 RED SPOTTY PAPER PLATES)
# 23                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 24                          (TEA PARTY BIRTHDAY CARD)
# 25                           (WOODLAND CHARLOTTE BAG)
# 26                    (SET/6 RED SPOTTY PAPER PLATES)
# 27                      (SET/6 RED SPOTTY PAPER CUPS)
# 28  (STRAWBERRY LUNCH BOX WITH CUTLERY, LUNCH BOX ...
# 29  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 30  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 31  (ROUND SNACK BOXES SET OF4 WOODLAND , ROUND SN...
# 32           (POSTAGE, SET/6 RED SPOTTY PAPER PLATES)
# 33             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)
# 34  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 35  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 36  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
#
#                         consequents  antecedent support  consequent support  \
# 0                         (POSTAGE)            0.060322            0.647453
# 1                         (POSTAGE)            0.056300            0.647453
# 2                         (POSTAGE)            0.069705            0.647453
# 3                         (POSTAGE)            0.072386            0.647453
# 4                         (POSTAGE)            0.060322            0.647453
# 5                         (POSTAGE)            0.077748            0.647453
# 6                         (POSTAGE)            0.069705            0.647453
# 7                         (POSTAGE)            0.067024            0.647453
# 8                         (POSTAGE)            0.099196            0.647453
# 9                         (POSTAGE)            0.065684            0.647453
# 10                        (POSTAGE)            0.127346            0.647453
# 11                        (POSTAGE)            0.068365            0.647453
# 12                        (POSTAGE)            0.142091            0.647453
# 13                        (POSTAGE)            0.130027            0.647453
# 14                        (POSTAGE)            0.100536            0.647453
# 15                        (POSTAGE)            0.063003            0.647453
# 16                        (POSTAGE)            0.085791            0.647453
# 17                        (POSTAGE)            0.180965            0.647453
# 18                        (POSTAGE)            0.104558            0.647453
# 19                        (POSTAGE)            0.148794            0.647453
# 20                        (POSTAGE)            0.079088            0.647453
# 21                        (POSTAGE)            0.116622            0.647453
# 22                        (POSTAGE)            0.107239            0.647453
# 23                        (POSTAGE)            0.107239            0.647453
# 24                        (POSTAGE)            0.076408            0.647453
# 25                        (POSTAGE)            0.080429            0.647453
# 26    (SET/6 RED SPOTTY PAPER CUPS)            0.107239            0.116622
# 27  (SET/6 RED SPOTTY PAPER PLATES)            0.116622            0.107239
# 28                        (POSTAGE)            0.068365            0.647453
# 29                        (POSTAGE)            0.084450            0.647453
# 30                        (POSTAGE)            0.076408            0.647453
# 31                        (POSTAGE)            0.064343            0.647453
# 32    (SET/6 RED SPOTTY PAPER CUPS)            0.091153            0.116622
# 33  (SET/6 RED SPOTTY PAPER PLATES)            0.099196            0.107239
# 34                        (POSTAGE)            0.097855            0.647453
# 35    (SET/6 RED SPOTTY PAPER CUPS)            0.060322            0.116622
# 36  (SET/6 RED SPOTTY PAPER PLATES)            0.060322            0.107239
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 0   0.052279    0.866667  1.338578               1.0  0.013223    2.644102
# 1   0.050938    0.904762  1.397417               1.0  0.014487    3.701743
# 2   0.065684    0.942308  1.455407               1.0  0.020553    6.110813
# 3   0.058981    0.814815  1.258492               1.0  0.012115    1.903753
# 4   0.050938    0.844444  1.304256               1.0  0.011883    2.266373
# 5   0.063003    0.810345  1.251588               1.0  0.012665    1.858884
# 6   0.065684    0.942308  1.455407               1.0  0.020553    6.110813
# 7   0.054960    0.820000  1.266501               1.0  0.011565    1.958594
# 8   0.085791    0.864865  1.335795               1.0  0.021566    2.608847
# 9   0.053619    0.816327  1.260827               1.0  0.011092    1.919422
# 10  0.103217    0.810526  1.251869               1.0  0.020767    1.860664
# 11  0.054960    0.803922  1.241668               1.0  0.010697    1.797989
# 12  0.113941    0.801887  1.238525               1.0  0.021944    1.779523
